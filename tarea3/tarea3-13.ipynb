# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

print("Opciones de funcion \n1.- 3*x+np.sin(x)-2.718**x\n2.- 5/(((x-(1/x))**(1/2)))\n3.- 4*x**4+9*x**3-5*x**2+9*x-9\n4.- 2.718**(x)+((x)**(1/2))-2\n5.- 2*x**3-x**2-8*x+4\n6.- 1/((x-2)*(x**2+3*x+1))\n7.- 2.718**((x**3)+2*(x**2)+x+1)\n8.- (np.log(x))+(1/((x**2)-5)*(x-2))\n9.- 4*np.cos(np.log(x))\n10.- (x+2)/(5*(x**2)+12*x+14)\n11.- 4*x**2+4*x+17")

funtion = int(input("Ingresar número de la función deseada: "))

if(funtion==1):
    def f(x):
        return 3*x+np.sin(x)-2.718**x
if(funtion==2):
    def f(x):
        return 5/(((x-(1/x))**(1/2)))
if(funtion==3):
    def f(x):
        return 4*x**4+9*x**3-5*x**2+9*x-9
if(funtion==4):
    def f(x):
        return 2.718**(x)+((x)**(1/2))-2
if(funtion==5):
    def f(x):
        return 2*x**3-x**2-8*x+4
if(funtion==6):
    def f(x):
        return 1/((x-2)*(x**2+3*x+1))
if(funtion==7):
    def f(x):
        return 2.718**((x**3)+2*(x**2)+x+1)
if(funtion==8):
    def f(x):
        return (np.log(x))+(1/((x**2)-5)*(x-2))
if(funtion==10):
    def f(x):
        return 4*np.cos(np.log(x))
if(funtion==11):
    def f(x):
        return (x+2)/(5*(x**2)+12*x+14)
if(funtion==12):
    def f(x):
        return 4*x**2+4*x+17

tol = 0.001

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

point = int(round(1/tol))
x = np.linspace(-10, 10, point)
y = f(x)

plt.plot(x, y, lw=1, color='r')
plt.grid(True, linestyle='-')

a = float(input("Ingresar limite inferior: "))
b = float(input("Ingresar limite superior: "))
#a = 1
#b = 2
c = (a + b) / 2.0

while (b - a) / 2.0 > tol:
    print ("{:f} {:f} {:f}".format(a, c, b))
    if f(c) == 0:
        break
    elif f(a) * f(c) < 0:
        b = c
    else:
        a = c
    c = (a + b) / 2.0

print("La raiz aprox. es: ")
print(c)
