# %%
import numpy
dec = float(input("Ingrese un numero decimal : ")) 
ent = int(dec)
pdec = dec - ent

if ent >= 0 :
    print("el decimal en modo binario es :: ")
    m =''
    while ent >= 1 :
        modulo1 = ent % 2
        m= str(modulo1) + m
        ent = int(ent/2)
    print(m)
    co=0
    z=0
    y=''
    while co<=22:
        x = pdec * 2
        z = int(x)
        y = y + str(z) 
        pdec = x - z
        co=co+1
if ent < 0 :
    print("el decimal en modo binario es:: ")
    pos=ent * -1
    m =''
    while pos >= 1:
        modulo2 = pos % 2
        m = str(modulo2) + m
        pos = int(pos/2)
    decpos = (dec* - 1) + int(dec) 
    co=0
    z=0
    y=''
    while co<=22:
            x = decpos * 2
            z = int(x)
            y = y + str(z)
            decpos = x - z
            co=co+1
c= len(m)
h=(c-1)+127
if h== 127:
    a='01111111'
a =''
while h >= 1 :
    mo = h % 2
    a= str(mo) + a
    h = int(h/2)       
g = m[1:c]+y
j = g[0:23]

if dec > 0 :
    print('0'+a+j)
if dec < 0 :
    print('1'+a+j)
