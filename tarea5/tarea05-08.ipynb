# %%
print("                        \033[1;30m"+"******************************************************"+'\033[0;m')
print("                        \033[1;30m"+"*    PROBLEMA DE LA SUPERNOVA EN SISTEMAS BINARIOS   *"+'\033[0;m')
print("                        \033[1;30m"+"*                                                    *"+'\033[0;m')
print("                      \033[1;30m"+"  *  REALIZADO POR NICOLAS RINCON Y CRISTIAN BELTRAN   *"+'\033[0;m')
print("                        \033[1;30m"+"*                                                    *"+'\033[0;m')
print("                        \033[1;30m"+"*                 METODOS NUMERICOS                  *"+'\033[0;m')
print("                        \033[1;30m"+"*                                                    *"+'\033[0;m')
print("                        \033[1;30m"+"*                 ING.JAVIER ENCISO                  *"+'\033[0;m')
print("                        \033[1;30m"+"*                                                    *"+'\033[0;m')
print("                        \033[1;30m"+"******************************************************"+'\033[0;m')
print("")



print("PLANTEAMIENTO DE LAS ECUACIONES NECESARIAS EN EL SISTEMAS BINARIO")

#def abrir_imagen(im):
 #   tiempoIn=time.time()
  #  ruta= ("C:\Users\one world united\Pictures" + im)
   # im=image.open(ruta)
    #im.show()
    #tiempoFin=time.time()
    #t=tiempoFin-tiempoIn
    #print("El muestreo tardó:", t , "segundos" )
    
print("PLANTEAMIENTO DE LAS ECUACIONES NECESARIAS EN EL SISTEMAS BINARIO")

print("Constante Dada Para La Excentricidad: ")
print("e= 0.617155 ± 0.000007")
print("")

print("El Periodo Orbital:")
print("T=27,906,98172 ± 0.00005 s")
print("")
print("Proyección Del Semi Eje Mayor Del Pulsar")
print("a1sini = 2.3424 ± 0.0007 Lights = (7.0223 ± 0.002)x10^10 cm")
print("")
print("Tasa De Avance De Periastron")
print(" w = 4.226 ± 0.002 yr-1")
print("")
print("Seno De Ángulo De Inclinación ")
print("sini = 0.81 ± 0.16")
print("")
print("Funcion Que Representa La Masa:")
print("F = 0.13126 +- 0.00002 M")
print("")
print("Centro De Masa Respecto A La Explosión")
print("R=([(Qm1)r1+m2r2])/((Qm1+m2))")
print("Entendiendo que la variable Qm es la masa que queda después de la explosión.")
print("")
print("Velocidad Relativa Del Binario Tiempo Antes De La Explosión")
print("v**2=(G(m1+m2))/a0 ")
print("")
print("Energía Resultante Del Movimiento Del Sistema Binario Después De La Explosión Es:")
print("E=[1/2(qm1)v1^2]+[1/2(m2)^2(v2)^2]-[1/2(qm1+m2)R^2]-[G(qm1)m2/a0]")
print("")
print("La Energía Total Del Binario Se Puede Simplificar, Obteniendo Así:")
print(" E=1/2m(v)^2[q(m1-m2-2qm1)/((qm1+m2))]")
print("")
print("Concepto Del Criterio Blaauw")
print(" la velocidad relativa antes de que la explosión sea mayor que el cuadrado de la velocidad de escape después de la explosión.")
print("(G(m1+m2))/a0 = v^2>v^2esc=(2G(qm1+m2))/a0 ")
print("")
print("El semieje Mayor Del Binario Después De La Explosión, Relacionado Con La Energía Total Sobre El Centro De Masa En La Siguiente Ecuación")
print("E= G(Q m1 m2)/2a")
print("")
print("El momento angular del binario final alrededor del centro de masa esta dado por:")
print("I´=I0(q(m1+m2))/((qm1+m2)) = I0f1(m1,m2,q)")
print("")
print("La excentricidad de la órbita final va a estar definida como:")
print("a(1-e^2) = I´^2/(m´k´)")
print("")
print("Si la órbita inicial es circular esta dada por la ecuación:")
print("a0 = I0^2/mk")
print("Se sabe que m representa la masa reducida del binario original y k = (G m1 m2).")
print("")
print("La velocidad regional del binario en su forma original:")
print("dA0/dt = 1/2(r0)^2(?0) = i0/2m")
print("")
print("La velocidad del centro de masa después de la explosión se deduce de la siguiente manera")
print(" Vcm=((1-q)m2*v2)/((qm1+m2))")
print("")
print("El centro de  la masa se desplaza en la misma dirección del movimiento de la estrella sin colisionar cuya velocidad esta dada por:")
print("VCM = m(1-q)/((qm1+m2))((G(m1+m2))/a0)^(1/2)")
print("")
print("La velocidad relativa mínima del binario se representa como:")
print("Vmin=[((1-e))/(1+e)^(1/2)]v")
print("")
print("DE IGUAL FORMA SE PRETENDE IMPLEMENTAR LAS ECUACIONES DEL MOVIMIENTO :")
print("")
print("La Primera Está Dada por: d/dt(dx1/dt)=(Gm2/r^2)cos?")
print("")
print("La Segunda Está Dada por: d/dt(dy1/dt)=(Gm2/r^2)sin?")
print("")
print("El ángulo comprendido por el cuerpo se implementa de la siguiente forma:")
print("")
print("cosf=v1/[v1^2+v8^2]^(1/2) =m2/[m1^2-2qm1(m1+m2)]^(1/2)")
print("")
print("IMPLEMENTACIÓN DE LA ECUACIÓN DE KEPLER ")
print("")
print(" v-esenv=(2pi/T)(T-T0)=n(t-t0)=M")
print("")
print("M=E- e senE1")
print("")
print("Donde e es la anomalía excéntrica.")
print("")
print("M es la anomalía media o ángulo que recorrería un planeta ficticio que se moviese con movimiento uniforme por la circunferencia principal")
print("")
print("e(0<e<1) es la excentricidad de la elipse")
# Out:
#                         ******************************************************
#                         *    PROBLEMA DE LA SUPERNOVA EN SISTEMAS BINARIOS   *
#                         *                                                    *
#                         *  REALIZADO POR NICOLAS RINCON Y CRISTIAN BELTRAN   *
#                         *                                                    *
#                         *                 METODOS NUMERICOS                  *
#                         *                                                    *
#                         *                 ING.JAVIER ENCISO                  *
#                         *                                                    *
#                         ******************************************************
#
# PLANTEAMIENTO DE LAS ECUACIONES NECESARIAS EN EL SISTEMAS BINARIO
# PLANTEAMIENTO DE LAS ECUACIONES NECESARIAS EN EL SISTEMAS BINARIO
# Constante Dada Para La Excentricidad:
# ...
